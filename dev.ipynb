# %%
import web_crawler as wc

# %%
wc.query_google("catan")
# Out:
# ✅ Downloaded pdfs\catan_base_rules_2020_200707.pdf

# %%
import pdfplumber
pdf_path = "pdfs/catan_base_rules_2020_200707.pdf"

def extract_text_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        return "".join(page.extract_text() or "" for page in pdf.pages).replace("\n"," ")

# %%
pdf_text
# Out:
# 'Klaus Teuber GG RR aammee uulleess aa && llmmaannaaccDear Settlers, To make it as easy as possible for you to start playing Catan , we use an award-winning rules system, which consists ® of 3 parts. First, if you do not know how to play Catan, please read the Game Overview on page 16 (the back cover). Next, read the Game Rules on pages 2-6 (red borders) and start to play the game. If you have questions during the game, consult the Catan Almanac on pages 6-15 (gold borders). Now you are ready for your first adventure on Catan. Have fun settling this new land together! — Klaus Teuber You can find further information at: catan.com catanstudio.com klausteuber.com G R ame ules These 4-page rules (pages 2-5) contain all the important ConstruCtinG the island information that you need to play! The frame pieces hold the board together and prevent If you need more information during the game, you can look the pieces from moving after the board is in place. Before up keywords (marked Y) in the “Almanac,” which follows building the island, assemble the frame by matching the these rules. numbers at the ends of the frame pieces together (i.e., 1-1, 2-2, etc.). Game Components You can then construct the island of Catan using the 19 • 19 terrain hexes (tiles) terrain hexes as shown on page 3. • 6 sea frame pieces Starting Set-up for Beginners • 9 harbor pieces • 18 circular number tokens You can play the game Catan on a variable game board. For your first game, however, we suggest that you use the • 95 resource cards (bearing the symbols for the brick, “Starting Set-up for Beginners Y.” (See Illus. A on page 3.) grain, lumber, ore, and wool resources) This set-up is well-balanced for all players. • 25 development cards (14 knight cards, 6 progress cards, 5 victory point cards) Before your first game, you must remove the die-cut components from the cardboard holders. Carefully punch • 4 “Building Costs” cards out and separate the pieces. When punching tiles out of the • 2 special cards: “Longest Road” & “Largest Army” die-cut sheets, always push the tiles through from the front, • 16 cities (4 of each color, shaped like churches) “cut” side (pushing from the back may cause the tiles to rip). • 20 settlements (5 of each color, shaped like houses) Lay out the map as specified in Illustration A (or on the • 60 roads (15 of each color, shaped like bars) back of this booklet). • 2 dice (1 yellow, 1 red) First, assemble the frame as shown. Second, create Catan • 1 robber by placing the 19 terrain hexes on the table—again as • 1 “Game Rules & Almanac” booklet shown. Third, place the circular number tokens on top of the designated terrain hexes. Finally, place your settlements and roads. Africa is spring and we walk five paths toward the sun 22Illustration A Starting Map Begin the game with for Beginners the resource cards produced by the To make it as easy as possible settlements for you to get started with marked with Catan, we use an award- 1100 22 99 white stars. winning rules system, which •••••• •• •••••••• See HH . consists of 3 parts—the Overview, the Game HH Rules, and 1122 66 44 1100 •• •••••••••• •••••• •••••• the Almanac. If you’ve never played Catan, HH 99 1111 33 88 please read the •••••••• •••• •••• •••••••••• RRoobbbbeerr game Overview first—it’s on the back cover of this 88HH 33 HH 44 55 •••••••••• •••• •••••• •••••••• booklet. Next, read the Odds fOr Game Rules and start dice rOlls to play. And finally, if you 55 66 1111 2 & 12 = 3% have questions during the •••••••• •••••••••• •••• 3 & 11 = 6% game, please consult the 4 & 10 = 8% Almanac (it begins on page 6). 5 & 9 = 11% 6 & 8 = 14% Resource Production 7 = 17% Hills Forest Mountains Fields Pasture Desert Produce Brick Produces Lumber Produce Ore Produce Grain Produces Wool Produces Nothing Starting Set-up for Experienced Players Place the special cards “Longest Road” and “Largest Army” beside the game board along with the 2 dice. It is more fun to play with a variable game board—w ...
